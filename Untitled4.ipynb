# %%
import pandas as pd
df=pd.read_csv('house.csv')
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df[['id','price','bedrooms','sqft_living','floors']].head()
# Out:
#            id   price  bedrooms  sqft_living  floors
# 0  7129300520  221900         3         1180     1.0
# 1  6414100192  538000         3         2570     2.0
# 2  5631500400  180000         2          770     1.0
# 3  2487200875  604000         4         1960     1.0
# 4  1954400510  510000         3         1680     1.0

# %%
df[df.floors>2][['id','bedrooms']].head()
# Out:
#              id  bedrooms
# 31   2426039314         2
# 63   9528102996         3
# 116  3362400431         3
# 134  2767602356         4
# 139  2767603505         3

# %%
df[(df.floors>2)&(df.bedrooms>3)].head()
# Out:
#              id             date    price  bedrooms  bathrooms  sqft_living  \
# 134  2767602356  20150126T000000   675000         4       3.50         2140
# 484  2625069070  20150410T000000  1385000         4       3.25         4860
# 518  4386700135  20141114T000000  2250000         4       2.25         4760
# 577  1526069135  20141211T000000   930000         4       4.00         6050
# 667  3300701615  20140930T000000   655000         4       2.50         2630
#
#      sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 134      2278     3.0           0     0  ...      9        2140
# 484    181319     2.5           0     0  ...      9        4860
# 518      8036     2.5           0     0  ...      9        3390
# 577     84942     2.5           0     2  ...      9        4150
# 667      4000     3.0           0     0  ...      8        2630
#
#      sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df[df.zipcode.isin([98107,98074,98112])].head()
# Out:
#             id             date   price  bedrooms  bathrooms  sqft_living  \
# 4   1954400510  20150218T000000  510000         3       2.00         1680
# 13  6054650070  20141007T000000  400000         3       1.75         1370
# 14  1175000570  20150312T000000  530000         5       2.00         1810
# 27  3303700376  20141201T000000  667000         3       1.00         1400
# 37  2768000400  20141230T000000  640000         4       2.00         2360
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 4       8080     1.0           0     0  ...      8        1680              0
# 13      9680     1.0           0     0  ...      7        1370              0
# 14      4850     1.5           0     0  ...      7        1810              0
# 27      1581     1.5           0     0  ...      8        1400              0
# 37      6000     2.0           0     0  ...      8        2360              0
#
# ...

# %%
df[(df.price>460000)&(df.price<550000)].head()
# Out:
#             id             date   price  bedrooms  bathrooms  sqft_living  \
# 1   6414100192  20141209T000000  538000         3       2.25         2570
# 4   1954400510  20150218T000000  510000         3       2.00         1680
# 11  9212900260  20140527T000000  468000         2       1.00         1160
# 14  1175000570  20150312T000000  530000         5       2.00         1810
# 17  6865200140  20140529T000000  485000         4       1.00         1600
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 1       7242     2.0           0     0  ...      7        2170            400
# 4       8080     1.0           0     0  ...      8        1680              0
# 11      6000     1.0           0     0  ...      7         860            300
# 14      4850     1.5           0     0  ...      7        1810              0
# 17      4300     1.5           0     0  ...      7        1600              0
#
# ...

# %%
df[(df.price>460000)&(df.price<550000)].shape
# Out:
# (2703, 21)

# %%
df.loc[df.price<460000,'zipcode'].shape
# Out:
# (11121,)

# %%
df['price'].min()
# Out:
# 75000

# %%
df['price'].max()
# Out:
# 7700000

# %%
df[df.price==75000][['zipcode','bedrooms','bathrooms','floors']]
# Out:
#       zipcode  bedrooms  bathrooms  floors
# 1149    98022         1        0.0     1.0

# %%
df.drop(['sqft_living'],axis=1,inplace=True)

# %%
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_lot  floors  \
# 0  7129300520  20141013T000000  221900         3       1.00      5650     1.0
# 1  6414100192  20141209T000000  538000         3       2.25      7242     2.0
# 2  5631500400  20150225T000000  180000         2       1.00     10000     1.0
# 3  2487200875  20141209T000000  604000         4       3.00      5000     1.0
# 4  1954400510  20150218T000000  510000         3       2.00      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...
